# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
def objective_function(x1, x2) -> float:
    return np.sin(x1)*np.cos(x2)
x1 = np.linspace(-10,10, 70, endpoint=False)
x2 = np.linspace(-10,10, 70, endpoint=False)

xx1, xx2 = np.meshgrid(x1, x2)

z = np.sin(xx1)*np.cos(xx2)

# %%
z.shape
# Out:
# (70, 70)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_wireframe(xx1, xx2, z)
